# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Soccer_Ranking.csv',skiprows=range(20, 465))

data = data.drop(labels=['prev_rank','off','def'], axis=1)

data.set_index('name')

print(data)
# Out:
#                    name                    league  rank   spi
# 0         bayern munich         german bundesliga     1  91.5
# 1           real madrid  spanish primera division     2  90.9
# 2       manchester city   barclays premier league     3  90.0
# 3             barcelona  spanish primera division     4  89.4
# 4             liverpool   barclays premier league     5  87.8
# 5   paris saint-germain            french ligue 1     6  85.7
# 6              juventus             italy serie a     7  84.6
# 7       atletico madrid  spanish primera division     8  82.5
# 8     tottenham hotspur   barclays premier league     9  82.5
# 9               as roma             italy serie a    10  80.8
# 10               napoli             italy serie a    11  80.8
# 11              arsenal   barclays premier league    12  80.5
# 12              chelsea   barclays premier league    13  78.5
# 13       internazionale             italy serie a    14  78.3
# ...

# %%
lines = data.plot.bar(x = 'name', rot = 0, title = "Top 20 soccer Teams", figsize=(35,20), fontsize=12)
